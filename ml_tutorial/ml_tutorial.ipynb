# %%
import numpy as np

# %%
x_data=np.random.randn(10)
w=np.random.randn(10)*2
w
# Out:
# array([ 4.54493616, -2.80806551,  2.40864215,  3.12517233,  0.43584391,
#        -2.45122663, -0.01928361, -1.83825072, -1.59665518,  1.75907457])

# %%
def a_neural(x):
    return 1/(1+np.exp(-x))

# %%
y_data=np.dot(x_data,w)

# %%
y_data
# Out:
# -0.5337512618964046

# %%
z=a_neural(y_data)

# %%
z
# Out:
# 0.36964239154172507

# %%
import matplotlib.pyplot as plt
from scipy.special import expit
x=np.arange(-10,10)
ytanh=np.tanh(y)
ysigmod=expit(y)
ysigmod1=2*(expit(y)-0.5)
plt.plot(x,ytanh,color="blue", linewidth=2.5, linestyle="-", label="y=tanh(x)") #tanh
plt.plot(x,ysigmod,c="red",label="y=sigmoid(x)")  #sigmoid
plt.plot(x,ysigmod1,c="cyan",label="y=sigmoid_shift(x)")  #sigmoid shift
plt.legend(loc='lower right')

plt.show()
